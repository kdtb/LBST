# %% [markdown]
# # Split into train and test
# In order to evaluate my models, I split my original dataset into a train set (80% of the photographs) and a test set (20% of the photographs). Thus, I set aside 20% of photographs, that I will not see before the very end where I want to see how well my models generalize.

# %%
from createCSV import TrainTest
import config

if __name__ == "__main__":
    csv = TrainTest(
        base_dir = config.BASE_DIR,
        all_csv = config.ALL_CSV,
        train_csv = config.TRAIN_CSV,
        test_csv = config.TEST_CSV,
        label_column = config.LABEL_COLUMN,
        test_size = config.TEST_SIZE,
        seed = config.SEED)
    csv.set_all_seeds()
    csv.df()
# Out:
# Train set length:
# 13036
# Test set length:
# 3434
# Train set label distribution:
# 0    12180
# 1      856
# Name: label, dtype: int64
# Test set label distribution:
# 0    3184
# 1     250
# Name: label, dtype: int64

# %% [markdown]
# ## Copy photographs into train/test folders on desktop

# %% [markdown]
# ### Copy to train folder

# %%
# Code to copy train images from the 'All' folder into a 'Train' folder.
# The purpose of this is to be able to generate experimental datasets

import os
import pandas as pd
import shutil

src_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/all"
dst_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train"

trainfiles = pd.read_csv(r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train_set.csv")
trainfiles = trainfiles['file_name'].tolist()
trainfiles[:10]
# Out:
# ['21-0176350_F87DA5781A30D81CE0530EEE260ADB63.jpeg',
#  '21-0176350_F87DA5781A32D81CE0530EEE260ADB63.jpeg',
#  '21-0176350_F87DA5782501D81CE0530EEE260ADB63.jpeg',
#  '21-0176350_F87DA5782502D81CE0530EEE260ADB63.jpeg',
#  '21-0176350_F87DA5782503D81CE0530EEE260ADB63.jpeg',
#  '21-0176367_F87DA57823CDD81CE0530EEE260ADB63.jpeg',
#  '21-0176367_F87DA57823CED81CE0530EEE260ADB63.jpeg',
#  '21-0176367_F87DA57823FDD81CE0530EEE260ADB63.jpeg',
#  '21-0176367_F87DA57823FED81CE0530EEE260ADB63.jpeg',
#  '21-0176388_F87DA5781407D81CE0530EEE260ADB63.jpeg']

# %%
# Loop that moves all train photographs into a train folder

for filename in trainfiles:
    src_path_file = os.path.join(src_path, filename)
    dst_path_file = os.path.join(dst_path, filename)
    shutil.copy(src_path_file, dst_path_file)

# %% [markdown]
# #### Copy trainfiles into separate approved and nonapproved folders
#
# I copy trainfiles into separate Approved and NonApproved folders, so that

# %%
# Code to copy approved train images from the 'train' folder into a 'train_approved' folder.
# The purpose of this is to be able to generate experimental datasets

src_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train"
dst_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train_approved"

train_approved = pd.read_csv(r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train_set.csv")
train_approved = train_approved[train_approved['label'] == 0]

train_approved = train_approved['file_name'].tolist()

# Loop that moves all train photographs into a train folder

for filename in train_approved:
    src_path_file = os.path.join(src_path, filename)
    dst_path_file = os.path.join(dst_path, filename)
    shutil.copy(src_path_file, dst_path_file)

# %%
# Code to copy nonapproved train images from the 'train' folder into a 'train_nonapproved' folder.
# The purpose of this is to be able to generate experimental datasets

src_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train"
dst_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train_nonapproved"

train_nonapproved = pd.read_csv(r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/train_set.csv")
train_nonapproved = train_nonapproved[train_nonapproved['label'] == 1]

train_nonapproved = train_nonapproved['file_name'].tolist()

# Loop that moves all train photographs into a train folder

for filename in train_nonapproved:
    src_path_file = os.path.join(src_path, filename)
    dst_path_file = os.path.join(dst_path, filename)
    shutil.copy(src_path_file, dst_path_file)

# %% [markdown]
# ### Copy to test folder

# %%
src_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/all"
dst_path = r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/test"

testfiles = pd.read_csv(r"C:/Users/kaspe/OneDrive - Aarhus Universitet/Skrivebord/BI/4. semester/Data/LBST/test_set.csv")
testfiles = testfiles['file_name'].tolist()
testfiles[:10]
# Out:
# ['21-0176543_F87DA5781C97D81CE0530EEE260ADB63.jpeg',
#  '21-0176543_F87DA5781C98D81CE0530EEE260ADB63.jpeg',
#  '21-0178467_F87DA57818F2D81CE0530EEE260ADB63.jpeg',
#  '21-0178467_F87DA57818F3D81CE0530EEE260ADB63.jpeg',
#  '21-0178467_F87DA57818F4D81CE0530EEE260ADB63.jpeg',
#  '21-0178467_F87DA57819ADD81CE0530EEE260ADB63.jpeg',
#  '21-0178467_F87DA57819AED81CE0530EEE260ADB63.jpeg',
#  '21-0178770_F87DA57827BCD81CE0530EEE260ADB63.jpeg',
#  '21-0178770_F87DA578280AD81CE0530EEE260ADB63.jpeg',
#  '21-0178770_F87DA5782810D81CE0530EEE260ADB63.jpeg']

# %%
# Loop that moves all test photographs into a test folder

for filename in testfiles:
    src_path_file = os.path.join(src_path, filename)
    dst_path_file = os.path.join(dst_path, filename)
    shutil.copy(src_path_file, dst_path_file)

# %% [markdown]
# ## Verify evaluation protocol
# Make two train/val splits to verify evaluation protocol. If val measures are somewhat the same, the train/valid/test evaluation protocol is reliable, and k-fold cross validation is then not needed.

# %%
from createCSV import TrainVal
import config

if __name__ == "__main__":
    csv1 = TrainVal(
        orig_train_csv = config.TRAIN_CSV,
        train_csv = config.TRAIN_CSV_1,
        val_csv = config.VAL_CSV_1,
        label_column = config.LABEL_COLUMN,
        val_size = config.VAL_SIZE,
        seed = config.SEED)
    csv1.set_all_seeds()
    csv1.df()
# Out:
# Original train set length:
# 13036
# New train set length and first n rows:
# 10244
#                                           file_name  label   parcel_id
# 0  21-0176350_F87DA5781A30D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 1  21-0176350_F87DA5781A32D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 2  21-0176350_F87DA5782501D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 3  21-0176350_F87DA5782502D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 4  21-0176350_F87DA5782503D81CE0530EEE260ADB63.jpeg      0  21-0176350
# Val set length and first n rows:
# 2792
#                                            file_name  label   parcel_id
# 32  21-0176564_F87DA5781289D81CE0530EEE260ADB63.jpeg      0  21-0176564
# 33  21-0176564_F87DA57819B5D81CE0530EEE260ADB63.jpeg      0  21-0176564
# 34  21-0176564_F87DA57819B6D81CE0530EEE260ADB63.jpeg      0  21-0176564
# 35  21-0176564_F87DA5781A19D81CE0530EEE260ADB63.jpeg      0  21-0176564
# ...

# %%
from createCSV import TrainVal
import config

if __name__ == "__main__":
    csv2 = TrainVal(
        orig_train_csv = config.TRAIN_CSV,
        train_csv = config.TRAIN_CSV_2,
        val_csv = config.VAL_CSV_2,
        label_column = config.LABEL_COLUMN,
        val_size = config.VAL_SIZE,
        seed = config.SEED_2) # other seed ensuring a new unique split
    csv2.set_all_seeds()
    csv2.df()
# Out:
# Original train set length:
# 13036
# New train set length and first n rows:
# 10425
#                                           file_name  label   parcel_id
# 0  21-0176350_F87DA5781A30D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 1  21-0176350_F87DA5781A32D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 2  21-0176350_F87DA5782501D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 3  21-0176350_F87DA5782502D81CE0530EEE260ADB63.jpeg      0  21-0176350
# 4  21-0176350_F87DA5782503D81CE0530EEE260ADB63.jpeg      0  21-0176350
# Val set length and first n rows:
# 2611
#                                            file_name  label   parcel_id
# 68  21-0178213_F87DA5782390D81CE0530EEE260ADB63.jpeg      0  21-0178213
# 69  21-0178213_F87DA5782393D81CE0530EEE260ADB63.jpeg      0  21-0178213
# 70  21-0178213_F87DA5782394D81CE0530EEE260ADB63.jpeg      0  21-0178213
# 71  21-0178213_F87DA5782395D81CE0530EEE260ADB63.jpeg      0  21-0178213
# ...

# %%
from calculateMeanStd import MeanStdModule
import config
import torch

loader = MeanStdModule(
    config.DATA_DIR,
    config.TRAIN_CSV,
    batch_size=32,
    num_workers=1
)
loader.setup(stage = 'train')
loader.train_dataloader()

mean = 0.
std = 0.
nb_samples = 0.

for data in loader.train_dataloader():
    data = data[0]
    batch_samples = data.size(0)
    data = data.view(batch_samples, data.size(1), -1)
    mean += data.mean(2).sum(0)
    std += data.std(2).sum(0)
    nb_samples += batch_samples

mean /= nb_samples
std /= nb_samples

mean = mean.tolist()
std = std.tolist()
print('Train set mean and std.', '\nMean: ', mean, '\nStd: ', std)
# Out:
# Train set mean and std.
# Mean:  [0.48643434047698975, 0.5090485215187073, 0.40648937225341797]
# Std:  [0.1766146421432495, 0.17801520228385925, 0.21651023626327515]

# %%
from torchvision.models import vgg16, VGG16_Weights

weights = VGG16_Weights.IMAGENET1K_V1
preprocess_transform = weights.transforms()

preprocess_transform
# Out:
# ImageClassification(
#     crop_size=[224]
#     resize_size=[256]
#     mean=[0.485, 0.456, 0.406]
#     std=[0.229, 0.224, 0.225]
#     interpolation=InterpolationMode.BILINEAR
# )

# %% [markdown]
# ## Train model 1

# %%
# Train model
from model import NN
from customDataModule import CustomDataModule
import config
import pytorch_lightning as pl
from lightning.pytorch.loggers import TensorBoardLogger
from pytorch_lightning.loggers import CSVLogger
from lightning.pytorch import seed_everything
from pytorch_lightning.callbacks import ModelCheckpoint
import torch
import torchvision.models as models
import torch.nn as nn

seed_everything(
    42, workers=True
)  # By setting workers=True in seed_everything(), Lightning derives unique seeds across all dataloader workers and processes for torch, numpy and stdlib random number generators. When turned on, it ensures that e.g. data augmentations are not repeated across workers.


callbacks = [ModelCheckpoint(
    save_top_k=1, mode='min', monitor="val_loss")]  # save top 1 model 


if __name__ == "__main__":
    
    pytorch_model = models.vgg16(weights='VGG16_Weights.DEFAULT')
    
    logger = TensorBoardLogger("tb_logs", name="verify_model_1") # tb_logs is the folder, name is the name of the experiment/model
    logger2 = CSVLogger(save_dir="logs/", name="verify_model_1")
    
    model = NN(
        model=pytorch_model,
        input_shape=config.INPUT_SHAPE,
        num_classes=config.NUM_CLASSES,
        learning_rate=config.LEARNING_RATE,
    )  # .to(device)
    dm = CustomDataModule(
        data_dir=config.DATA_DIR,
        train_csv=config.TRAIN_CSV_1,
        val_csv=config.VAL_CSV_1,
        test_csv=config.TEST_CSV,
        batch_size=config.BATCH_SIZE,
        num_workers=config.NUM_WORKERS,
        mean=config.MEAN,
        std=config.STD
    )
    
    trainer = pl.Trainer(
        logger=[logger2, logger],
        accelerator=config.ACCELERATOR,
        devices=config.DEVICES,
        min_epochs=config.MIN_EPOCHS,
        max_epochs=config.MAX_EPOCHS,
        deterministic=config.DETERMINISTIC,
        callbacks=callbacks
    )
      # deterministic ensures random seed reproducibility

    trainer.fit(model, dm)  # it will automatically know which dataloader to use
    
# A general place to start is to set num_workers equal to the number of CPU cores on that machine. You can get the number of CPU cores in python using os.cpu_count(), but note that depending on your batch size, you may overflow RAM memory.
# Out:
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: logs/verify_model_1
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | model     | VGG              | 134 M
# 1 | loss_fn   | CrossEntropyLoss | 0
# 2 | train_acc | BinaryAccuracy   | 0
# 3 | val_acc   | BinaryAccuracy   | 0
# -----------------------------------------------
# 8.2 K     Trainable params
# 134 M     Non-trainable params
# 134 M     Total params
# 537.075   Total estimated model params size (MB)
# Epoch 0: 100%|██████████| 321/321 [01:45<00:00,  3.04it/s, v_num=0]
# Validation: 0it [00:00, ?it/s]
# ...
# Epoch 1: 100%|██████████| 321/321 [01:46<00:00,  3.02it/s, v_num=0, train_loss=0.279, train_accuracy=0.920]
# Validation: 0it [00:00, ?it/s]
# ...

# %%
path = trainer.checkpoint_callback.best_model_path
print(path)
# Out:
# logs/verify_model_1\version_0\checkpoints\epoch=2-step=963.ckpt

# %%
trainer.validate(model=model, datamodule=dm, ckpt_path=path)
# Out:
# Restoring states from the checkpoint path at logs/verify_model_1\version_0\checkpoints\epoch=2-step=963.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at logs/verify_model_1\version_0\checkpoints\epoch=2-step=963.ckpt
# Validation DataLoader 0: 100%|██████████| 88/88 [00:26<00:00,  3.35it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       val_accuracy        │    0.9648997187614441     │
# │         val_loss          │    0.16584445536136627    │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.16584445536136627, 'val_accuracy': 0.9648997187614441}]

# %% [markdown]
# ## Train model 2

# %%
# Train model
from model import NN
from customDataModule import CustomDataModule
import config
import pytorch_lightning as pl
from lightning.pytorch.loggers import TensorBoardLogger
from pytorch_lightning.loggers import CSVLogger
from lightning.pytorch import seed_everything
from pytorch_lightning.callbacks import ModelCheckpoint
import torch
import torchvision.models as models
import torch.nn as nn

seed_everything(
    42, workers=True
)  # By setting workers=True in seed_everything(), Lightning derives unique seeds across all dataloader workers and processes for torch, numpy and stdlib random number generators. When turned on, it ensures that e.g. data augmentations are not repeated across workers.


callbacks = [ModelCheckpoint(
    save_top_k=1, mode='min', monitor="val_loss")]  # save top 1 model 


if __name__ == "__main__":
    
    pytorch_model = models.vgg16(weights='VGG16_Weights.DEFAULT')
    
    logger = TensorBoardLogger("tb_logs", name="verify_model_2") # tb_logs is the folder, name is the name of the experiment/model
    logger2 = CSVLogger(save_dir="logs/", name="verify_model_2")
    
    model = NN(
        model=pytorch_model,
        input_shape=config.INPUT_SHAPE,
        num_classes=config.NUM_CLASSES,
        learning_rate=config.LEARNING_RATE,
    )  # .to(device)
    dm = CustomDataModule(
        data_dir=config.DATA_DIR,
        train_csv=config.TRAIN_CSV_2,
        val_csv=config.VAL_CSV_2,
        test_csv=config.TEST_CSV,
        batch_size=config.BATCH_SIZE,
        num_workers=config.NUM_WORKERS,
        mean=config.MEAN,
        std=config.STD
    )
    
    trainer = pl.Trainer(
        logger=[logger2, logger],
        accelerator=config.ACCELERATOR,
        devices=config.DEVICES,
        min_epochs=config.MIN_EPOCHS,
        max_epochs=config.MAX_EPOCHS,
        deterministic=config.DETERMINISTIC,
        callbacks=callbacks
    )
      # deterministic ensures random seed reproducibility

    trainer.fit(model, dm)  # it will automatically know which dataloader to use
    
# A general place to start is to set num_workers equal to the number of CPU cores on that machine. You can get the number of CPU cores in python using os.cpu_count(), but note that depending on your batch size, you may overflow RAM memory.
# Out:
# Global seed set to 42
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: logs/verify_model_2
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | model     | VGG              | 134 M
# 1 | loss_fn   | CrossEntropyLoss | 0
# 2 | train_acc | BinaryAccuracy   | 0
# 3 | val_acc   | BinaryAccuracy   | 0
# -----------------------------------------------
# 8.2 K     Trainable params
# 134 M     Non-trainable params
# 134 M     Total params
# 537.075   Total estimated model params size (MB)
# Epoch 0: 100%|██████████| 326/326 [01:52<00:00,  2.89it/s, v_num=0]
# Validation: 0it [00:00, ?it/s]
# ...
# Epoch 1: 100%|██████████| 326/326 [01:46<00:00,  3.05it/s, v_num=0, train_loss=0.269, train_accuracy=0.926]
# Validation: 0it [00:00, ?it/s]
# ...

# %%
path = trainer.checkpoint_callback.best_model_path
print(path)
# Out:
# logs/verify_model_2\version_0\checkpoints\epoch=1-step=652.ckpt

# %%
trainer.validate(model=model, datamodule=dm, ckpt_path=path)
# Out:
# Restoring states from the checkpoint path at logs/verify_model_2\version_0\checkpoints\epoch=1-step=652.ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from the checkpoint at logs/verify_model_2\version_0\checkpoints\epoch=1-step=652.ckpt
# Validation DataLoader 0: 100%|██████████| 82/82 [00:26<00:00,  3.14it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │       val_accuracy        │    0.9494446516036987     │
# │         val_loss          │    0.19541534781455994    │
# └───────────────────────────┴───────────────────────────┘
# [{'val_loss': 0.19541534781455994, 'val_accuracy': 0.9494446516036987}]
